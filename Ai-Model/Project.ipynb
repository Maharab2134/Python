# %%
import csv

data = [
    {"ID": 1, "Message": "I always try to help others when they need it.", "Label": "Good"},
    {"ID": 2, "Message": "I often ignore people's requests for help.", "Label": "Bad"},
    {"ID": 3, "Message": "I respect people's personal space and boundaries.", "Label": "Good"},
    {"ID": 4, "Message": "I sometimes invade other people's privacy without asking.", "Label": "Bad"},
    {"ID": 5, "Message": "I appreciate when others are kind to me.", "Label": "Good"},
    {"ID": 6, "Message": "I feel irritated when people are polite to me.", "Label": "Bad"},
    {"ID": 7, "Message": "I always apologize when I make a mistake.", "Label": "Good"},
    {"ID": 8, "Message": "I never apologize, even if I know I’m wrong.", "Label": "Bad"},
    {"ID": 9, "Message": "I listen carefully when people are speaking.", "Label": "Good"},
    {"ID": 10, "Message": "I often interrupt others when they're talking.", "Label": "Bad"},
    {"ID": 11, "Message": "I love volunteering for community events.", "Label": "Good"},
    {"ID": 12, "Message": "I avoid participating in community events.", "Label": "Bad"},
    {"ID": 13, "Message": "I try to keep my promises to others.", "Label": "Good"},
    {"ID": 14, "Message": "I break promises without feeling guilty.", "Label": "Bad"},
    {"ID": 15, "Message": "I am always on time for meetings.", "Label": "Good"},
    {"ID": 16, "Message": "I frequently arrive late to meetings.", "Label": "Bad"},
    {"ID": 17, "Message": "I’m patient with people when they make mistakes.", "Label": "Good"},
    {"ID": 18, "Message": "I get frustrated when people make mistakes.", "Label": "Bad"},
    {"ID": 19, "Message": "I celebrate others' successes.", "Label": "Good"},
    {"ID": 20, "Message": "I feel jealous when others succeed.", "Label": "Bad"},
    {"ID": 21, "Message": "I try to maintain a positive attitude in difficult situations.", "Label": "Good"},
    {"ID": 22, "Message": "I often complain and focus on the negative.", "Label": "Bad"},
    {"ID": 23, "Message": "I respect people's opinions, even if I disagree.", "Label": "Good"},
    {"ID": 24, "Message": "I argue with people just to prove them wrong.", "Label": "Bad"},
    {"ID": 25, "Message": "I help my coworkers when they are overwhelmed.", "Label": "Good"},
    {"ID": 26, "Message": "I avoid helping others, even if I know they need it.", "Label": "Bad"},
    {"ID": 27, "Message": "I take care of my health and well-being.", "Label": "Good"},
    {"ID": 28, "Message": "I neglect my health and don't take care of myself.", "Label": "Bad"},
    {"ID": 29, "Message": "I encourage others to be their best selves.", "Label": "Good"},
    {"ID": 30, "Message": "I criticize others for their weaknesses.", "Label": "Bad"},
    {"ID": 31, "Message": "I am always respectful towards my friends.", "Label": "Good"},
    {"ID": 32, "Message": "I sometimes mock my friends in a hurtful way.", "Label": "Bad"},
    {"ID": 33, "Message": "I express gratitude for the things others do for me.", "Label": "Good"},
    {"ID": 34, "Message": "I rarely thank others for their efforts.", "Label": "Bad"},
    {"ID": 35, "Message": "I enjoy giving compliments to others.", "Label": "Good"},
    {"ID": 36, "Message": "I never compliment others, even if they deserve it.", "Label": "Bad"},
    {"ID": 37, "Message": "I help strangers when I can.", "Label": "Good"},
    {"ID": 38, "Message": "I ignore people in need, even if I could help.", "Label": "Bad"},
    {"ID": 39, "Message": "I am honest, even when it's difficult.", "Label": "Good"},
    {"ID": 40, "Message": "I lie to avoid trouble or responsibility.", "Label": "Bad"},
    {"ID": 41, "Message": "I stand up for what's right, even in challenging situations.", "Label": "Good"},
    {"ID": 42, "Message": "I stay silent when I see something wrong happening.", "Label": "Bad"},
    {"ID": 43, "Message": "I practice kindness every day.", "Label": "Good"},
    {"ID": 44, "Message": "I often act unkindly without realizing it.", "Label": "Bad"},
    {"ID": 45, "Message": "I keep my promises to family and friends.", "Label": "Good"},
    {"ID": 46, "Message": "I cancel plans at the last minute frequently.", "Label": "Bad"},
    {"ID": 47, "Message": "I treat everyone with respect, regardless of their background.", "Label": "Good"},
    {"ID": 48, "Message": "I discriminate against people based on their appearance or race.", "Label": "Bad"},
    {"ID": 49, "Message": "I give constructive feedback when needed.", "Label": "Good"},
    {"ID": 50, "Message": "I criticize without offering any helpful suggestions.", "Label": "Bad"},
    {"ID": 51, "Message": "I work well with a team to achieve common goals.", "Label": "Good"},
    {"ID": 52, "Message": "I prefer to work alone and avoid collaborating with others.", "Label": "Bad"},
    {"ID": 53, "Message": "I communicate clearly and effectively with others.", "Label": "Good"},
    {"ID": 54, "Message": "I struggle to express myself and often cause misunderstandings.", "Label": "Bad"},
    {"ID": 55, "Message": "I take responsibility for my actions.", "Label": "Good"},
    {"ID": 56, "Message": "I always blame others for my mistakes.", "Label": "Bad"},
    {"ID": 57, "Message": "I am mindful of how my words affect others.", "Label": "Good"},
    {"ID": 58, "Message": "I speak without considering how my words may hurt someone.", "Label": "Bad"},
    {"ID": 59, "Message": "I try to learn from my mistakes.", "Label": "Good"},
    {"ID": 60, "Message": "I ignore my mistakes and repeat them often.", "Label": "Bad"},
    {"ID": 61, "Message": "I encourage others to do their best.", "Label": "Good"},
    {"ID": 62, "Message": "I discourage others from trying new things.", "Label": "Bad"},
    {"ID": 63, "Message": "I forgive others when they hurt me.", "Label": "Good"},
    {"ID": 64, "Message": "I hold grudges and refuse to forgive.", "Label": "Bad"},
    {"ID": 65, "Message": "I remain calm during stressful situations.", "Label": "Good"},
    {"ID": 66, "Message": "I lose my temper easily during stressful situations.", "Label": "Bad"},
    {"ID": 67, "Message": "I admit when I don’t know something.", "Label": "Good"},
    {"ID": 68, "Message": "I pretend to know things I don’t understand.", "Label": "Bad"},
    {"ID": 69, "Message": "I give people a chance to explain themselves.", "Label": "Good"},
    {"ID": 70, "Message": "I cut people off before they can explain themselves.", "Label": "Bad"},
    {"ID": 71, "Message": "I help those in need, even if it requires a sacrifice.", "Label": "Good"},
    {"ID": 72, "Message": "I avoid helping others when it inconveniences me.", "Label": "Bad"},
    {"ID": 73, "Message": "I treat animals with kindness and care.", "Label": "Good"},
    {"ID": 74, "Message": "I mistreat animals, even if unintentionally.", "Label": "Bad"},
    {"ID": 75, "Message": "I avoid judging others based on first impressions.", "Label": "Good"},
    {"ID": 76, "Message": "I often judge people based on their appearance or background.", "Label": "Bad"},
    {"ID": 77, "Message": "I practice empathy and try to understand others’ feelings.", "Label": "Good"},
    {"ID": 78, "Message": "I dismiss others' feelings without consideration.", "Label": "Bad"},
    {"ID": 79, "Message": "I try to create a positive atmosphere in social settings.", "Label": "Good"},
    {"ID": 80, "Message": "I contribute to negativity in group conversations.", "Label": "Bad"}
]

csv_file = "behavior_data.csv"

with open(csv_file, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, fieldnames=["ID", "Message", "Label"])
    writer.writeheader()
    writer.writerows(data)

print(f"CSV file '{csv_file}' has been created successfully.")
# Out:
# CSV file 'behavior_data.csv' has been created successfully.

# %%
import pandas as pd
df = pd.read_csv('/content/behavior_data.csv')
df
# Out:
#     ID                                            Message Label
# 0    1     I always try to help others when they need it.  Good
# 1    2         I often ignore people's requests for help.   Bad
# 2    3  I respect people's personal space and boundaries.  Good
# 3    4  I sometimes invade other people's privacy with...   Bad
# 4    5           I appreciate when others are kind to me.  Good
# ..  ..                                                ...   ...
# 75  76  I often judge people based on their appearance...   Bad
# 76  77  I practice empathy and try to understand other...  Good
# 77  78  I dismiss others' feelings without consideration.   Bad
# 78  79  I try to create a positive atmosphere in socia...  Good
# 79  80  I contribute to negativity in group conversati...   Bad
#
# [80 rows x 3 columns]

# %%
y = df ['ID']
y
# Out:
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5
#       ..
# 75    76
# 76    77
# 77    78
# 78    79
# 79    80
# Name: ID, Length: 80, dtype: int64

# %%
x  = df.drop('ID', axis=1) #
x
# Out:
#                                               Message Label
# 0      I always try to help others when they need it.  Good
# 1          I often ignore people's requests for help.   Bad
# 2   I respect people's personal space and boundaries.  Good
# 3   I sometimes invade other people's privacy with...   Bad
# 4            I appreciate when others are kind to me.  Good
# ..                                                ...   ...
# 75  I often judge people based on their appearance...   Bad
# 76  I practice empathy and try to understand other...  Good
# 77  I dismiss others' feelings without consideration.   Bad
# 78  I try to create a positive atmosphere in socia...  Good
# 79  I contribute to negativity in group conversati...   Bad
#
# [80 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       80 non-null     int64
#  1   Message  80 non-null     object
#  2   Label    80 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 2.0+ KB
